# %%
import pandas as pd

# %%
df=pd.read_excel("Ch1_Q20_V12_Data_File.xlsx")

# %%
df.shape
# Out:
# (91, 15)

# %%
df.iloc[:,:4]
# Out:
#     Observation    x1     x2     x3
# 0             1  33.0  371.0  189.0
# 1             2  28.0  752.0    NaN
# 2             3  24.0  673.0  204.0
# 3             4  17.0    NaN  151.0
# 4             5  20.0   66.0  191.0
# ..          ...   ...    ...    ...
# 86           87  18.0  412.0  137.0
# 87           88  28.0  629.0  139.0
# 88           89  22.0  167.0  125.0
# 89           90  35.0  842.0  126.0
# 90           91  38.0  180.0  151.0
#
# [91 rows x 4 columns]

# %%
df_cleaned = df.iloc[:,:4]
# Out:
# (91, 4)

# %%
df_cleaned.shape
# Out:
# (91, 4)

# %%
df_cleaned = df.dropna(subset=df.columns[:4])

# %%
df_cleaned.shape
# Out:
# (82, 15)

# %%
#How many observations have x1 values greater than 30?

df_count_x1 = (df['x1'] > 30).sum()
df_count_x1
# Out:
# 17

# %%
df_cleaned[df_cleaned['x1']>30].shape
# Out:
# (17, 4)

# %%
#Sort the data by x1 in ascending order. what are the x1, x2, and x3 values of the first observation after the data are sorted?

#returns by default ascending order
df_cleaned.sort_values('x1')
# Out:
#     Observation    x1     x2     x3
# 50           51   2.0  335.0  166.0
# 58           59   4.0  257.0  144.0
# 40           41   6.0  992.0  150.0
# 16           17   6.0  999.0  156.0
# 81           82   7.0  430.0  160.0
# ..          ...   ...    ...    ...
# 11           12  39.0   62.0  128.0
# 45           46  41.0   71.0   94.0
# 35           36  43.0  768.0  140.0
# 69           70  57.0  218.0  154.0
# 20           21   NaN  850.0  162.0
#
# [91 rows x 4 columns]

# %%
#Sort the data by x1 in descending order. what are the x1, x2, and x3 values of the first observation after the data are sorted?

# Sort the DataFrame by 'x1' in descending order
df_sorted = df.sort_values(by='x1', ascending=False)

# Retrieve the 'x1', 'x2', and 'x3' values of the first observation
first_observation = df_sorted.iloc[0]  # Assuming you want the first row
x1_value = first_observation['x1']
x2_value = first_observation['x2']
x3_value = first_observation['x3']

# Print or use the values as needed
print(f"x1 value of the first observation after sorting: {x1_value}")
print(f"x2 value of the first observation after sorting: {x2_value}")
print(f"x3 value of the first observation after sorting: {x3_value}")
# Out:
# x1 value of the first observation after sorting: 57.0
# x2 value of the first observation after sorting: 218.0
# x3 value of the first observation after sorting: 154.0

# %%
#Sort the data by x1 in descending order. what are the x1, x2, and x3 values of the first observation after the data are sorted?
df_cleaned.sort_values('x1', ascending = False)
# Out:
#     Observation    x1     x2     x3
# 69           70  57.0  218.0  154.0
# 35           36  43.0  768.0  140.0
# 45           46  41.0   71.0   94.0
# 11           12  39.0   62.0  128.0
# 33           34  39.0  173.0  160.0
# ..          ...   ...    ...    ...
# 40           41   6.0  992.0  150.0
# 16           17   6.0  999.0  156.0
# 58           59   4.0  257.0  144.0
# 50           51   2.0  335.0  166.0
# 20           21   NaN  850.0  162.0
#
# [91 rows x 4 columns]

# %%
#How many missing values are there in x1, x2, and x3?

#returns False if not Nan, True if Nan

df_cleaned.isna()
# Out:
#     Observation     x1     x2     x3
# 0         False  False  False  False
# 1         False  False  False   True
# 2         False  False  False  False
# 3         False  False   True  False
# 4         False  False  False  False
# ..          ...    ...    ...    ...
# 86        False  False  False  False
# 87        False  False  False  False
# 88        False  False  False  False
# 89        False  False  False  False
# 90        False  False  False  False
#
# [91 rows x 4 columns]

# %%
#How many missing values are there in x1, x2, and x3?
df_cleaned.isna().sum()
#True is 1, False is 0
# Out:
# Observation    0
# x1             1
# x2             3
# x3             5
# dtype: int64
