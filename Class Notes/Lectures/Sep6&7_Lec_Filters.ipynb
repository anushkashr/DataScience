# %% [markdown]
# # September 6, Wednesday

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df_chipotle = pd.read_csv(url, sep = '\t')
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df_chipotle[df_chipotle.item_name == 'Chips and Fresh Tomato Salsa']
# Out:
#       order_id  quantity                     item_name choice_description  \
# 0            1         1  Chips and Fresh Tomato Salsa                NaN
# 25          13         1  Chips and Fresh Tomato Salsa                NaN
# 55          25         1  Chips and Fresh Tomato Salsa                NaN
# 89          39         1  Chips and Fresh Tomato Salsa                NaN
# 183         82         1  Chips and Fresh Tomato Salsa                NaN
# ...        ...       ...                           ...                ...
# 4231      1689         1  Chips and Fresh Tomato Salsa                NaN
# 4318      1722         1  Chips and Fresh Tomato Salsa                NaN
# 4324      1725         1  Chips and Fresh Tomato Salsa                NaN
# 4425      1764         1  Chips and Fresh Tomato Salsa                NaN
# 4503      1790         1  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 0        $2.39
# 25       $2.39
# 55       $2.39
# ...

# %% [markdown]
# Item_price is not in form of integer or float

# %%
df_chipotle.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
#Write a query so that $ should be removed and value should be converted into float value

for value in df_chipotle.item_price:
  print(value[1:-1])

#skipping $ and picking everything except $
prices = [float(value[1:-1]) for value in df_chipotle.item_price]
df_chipotle.item_price = prices

df_chipotle
# Out:
# 2.39
# 3.39
# 3.39
# 2.39
# 16.98
# 10.98
# 1.69
# 11.75
# 9.25
# 9.25
# 4.45
# 8.75
# 8.75
# 11.25
# 4.45
# 2.39
# 8.49
# 8.49
# 2.18
# 8.75
# 4.45
# 8.99
# 3.39
# 10.98
# 3.39
# 2.39
# 8.49
# 8.99
# 1.09
# 8.49
# 2.39
# 8.99
# 1.69
# 8.99
# 1.09
# 8.75
# 8.75
# 4.45
# 2.95
# 11.75
# 2.15
# 4.45
# 11.25
# 11.75
# 8.75
# 10.98
# 8.99
# 3.39
# 8.99
# 3.99
# 8.99
# 2.18
# 10.98
# 1.09
# 8.99
# 2.39
# 9.25
# 11.25
# 11.75
# 2.15
# 4.45
# 9.25
# 11.25
# 8.75
# 8.99
# 8.99
# 3.39
# 8.99
# 10.98
# 8.99
# 1.69
# 8.99
# 3.99
# 8.75
# 4.45
# 8.75
# 8.75
# 2.15
# 8.75
# 11.25
# 2.15
# 9.25
# 8.75
# 8.75
# 9.25
# 8.49
# 8.99
# 1.09
# 9.25
# 2.95
# 11.75
# 11.75
# 9.25
# 11.75
# 4.45
# 9.25
# 4.45
# 11.75
# 8.75
# 8.75
# 4.45
# 8.99
# 8.99
# 3.99
# 8.49
# 3.39
# 8.99
# 1.09
# 9.25
# 4.45
# 8.75
# 2.95
# 4.45
# 2.39
# 8.49
# 8.99
# 8.49
# 1.09
# 8.99
# 3.99
# 8.75
# 9.25
# 4.45
# 11.25
# 4.45
# 8.99
# 1.09
# 9.25
# 2.95
# 4.45
# 11.75
# 4.45
# 8.49
# 2.39
# 10.98
# 22.50
# 11.75
# 4.45
# 11.25
# ...

# %%
df_chipotle[df_chipotle.item_price > 10]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %%
#items not containing Tomatillo-Red Chili Salsa
df_chipotle[df_chipotle.choice_description != 'Tomatillo-Red Chili Salsa']
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
#Item name is Steak Burrito
df_chipotle[df_chipotle.item_name == 'Steak Burrito']
# Out:
#       order_id  quantity      item_name  \
# 7            4         1  Steak Burrito
# 9            5         1  Steak Burrito
# 31          16         1  Steak Burrito
# 43          20         1  Steak Burrito
# 46          21         1  Steak Burrito
# ...        ...       ...            ...
# 4546      1807         1  Steak Burrito
# 4607      1829         1  Steak Burrito
# 4610      1830         1  Steak Burrito
# 4617      1833         1  Steak Burrito
# 4618      1833         1  Steak Burrito
#
#                                      choice_description  item_price
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        9.25
# 31    [[Roasted Chili Corn Salsa (Medium), Fresh Tom...        8.99
# 43    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...       11.75
# 46    [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...        8.99
# ...                                                 ...         ...
# ...

# %%
df_chipotle.filter(like = 'item', axis=1)
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
df_chipotle.query('item_name == "Steak Burrito" & item_price > 15')
# Out:
#       order_id  quantity      item_name  \
# 148         67         2  Steak Burrito
# 353        152         2  Steak Burrito
# 534        223         2  Steak Burrito
# 549        229         2  Steak Burrito
# 638        264         2  Steak Burrito
# 1255       511         3  Steak Burrito
# 1262       513         2  Steak Burrito
# 1753       708         2  Steak Burrito
# 2380       947         2  Steak Burrito
# 2954      1175         2  Steak Burrito
# 3134      1250         2  Steak Burrito
# 3603      1443         3  Steak Burrito
# 3616      1449         2  Steak Burrito
# 3861      1548         2  Steak Burrito
# 3970      1591         2  Steak Burrito
# 4310      1719         2  Steak Burrito
#
#                                      choice_description  item_price
# 148   [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...       17.98
# 353   [Fresh Tomato (Mild), [Lettuce, Guacamole, Ric...       22.16
# 534   [Fresh Tomato Salsa, [Sour Cream, Lettuce, Che...       18.50
# ...

# %%
##rows 3 to 5, and all columns
df_chipotle.iloc[3:6, :]
# Out:
#    order_id  quantity                              item_name  \
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
#
#                                   choice_description  item_price
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98

# %%
df_chipotle[(df_chipotle['quantity'] >= 3) & (df_chipotle['item_price'] <= 10)]
# Out:
#       order_id  quantity                            item_name  \
# 689        284         3                    Canned Soft Drink
# 818        338         3                        Bottled Water
# 850        350         3                    Canned Soft Drink
# 917        379         3                    Canned Soft Drink
# 1425       577         4                        Bottled Water
# 1559       633         3                    Canned Soft Drink
# 1880       759         4                        Bottled Water
# 2235       901         4                          Canned Soda
# 2441       970         5                        Bottled Water
# 2823      1121         3                        Bottled Water
# 2936      1167         3                                Chips
# 2944      1170         3                        Side of Chips
# 2972      1182         3  Chips and Tomatillo-Red Chili Salsa
# 3089      1231         3                    Canned Soft Drink
# ...

# %%
df_chipotle.filter(items = ['choice_description', 'quantity'])
# Out:
#                                      choice_description  quantity
# 0                                                   NaN         1
# 1                                          [Clementine]         1
# 2                                               [Apple]         1
# 3                                                   NaN         1
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...         2
# ...                                                 ...       ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...         1
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...         1
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...         1
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...         1
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...         1
#
# [4622 rows x 2 columns]

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
df_users = pd.read_csv(url, sep='|')
df_users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
df_users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
df_users.ndim
# Out:
# 2

# %%
#Top 5 records
df_users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
#Bottom 5 records
df_users.tail()
# Out:
#      user_id  age gender     occupation zip_code
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
#when using groupby, there should be atleast one groupby function associated with that
df_users.groupby('occupation').sum()
# Out:
# <ipython-input-58-7f6ca651e188>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_users.groupby('occupation').sum()
#                user_id   age
# occupation
# administrator    34045  3061
# artist           12653   879
# doctor            3736   305
# educator         44356  3991
# engineer         30574  2438
# entertainment     7164   526
# executive        13514  1239
# healthcare        8023   665
# homemaker         3101   228
# lawyer            4309   441
# librarian        24816  2040
# marketing        11383   978
# none              3318   239
# other            56987  3625
# programmer       28745  2186
# retired           7220   883
# salesman          5939   428
# scientist        14419  1102
# student          95051  4328
# technician       13436   895
# ...

# %%
df_users.groupby('occupation').count()
# Out:
#                user_id  age  gender  zip_code
# occupation
# administrator       79   79      79        79
# artist              28   28      28        28
# doctor               7    7       7         7
# educator            95   95      95        95
# engineer            67   67      67        67
# entertainment       18   18      18        18
# executive           32   32      32        32
# healthcare          16   16      16        16
# homemaker            7    7       7         7
# lawyer              12   12      12        12
# librarian           51   51      51        51
# marketing           26   26      26        26
# none                 9    9       9         9
# other              105  105     105       105
# programmer          66   66      66        66
# retired             14   14      14        14
# salesman            12   12      12        12
# scientist           31   31      31        31
# student            196  196     196       196
# ...

# %%
df_users.groupby('occupation').age.count()
# Out:
# occupation
# administrator     79
# artist            28
# doctor             7
# educator          95
# engineer          67
# entertainment     18
# executive         32
# healthcare        16
# homemaker          7
# lawyer            12
# librarian         51
# marketing         26
# none               9
# other            105
# programmer        66
# retired           14
# salesman          12
# scientist         31
# student          196
# technician        27
# writer            45
# Name: age, dtype: int64

# %%
#Male and female ratio

# %%
df_users.groupby(['gender']).mean()
# Out:
# <ipython-input-63-14e588fe662f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_users.groupby(['gender']).mean()
#            user_id        age
# gender
# F       481.406593  33.813187
# M       468.167164  34.149254

# %%
df_users.zip_code.nunique()
# Out:
# 795

# %%
df_users.groupby("user_id").size()
# Out:
# user_id
# 1      1
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 939    1
# 940    1
# 941    1
# 942    1
# 943    1
# Length: 943, dtype: int64

# %%
df_users.groupby("age").count()
# Out:
#      user_id  gender  occupation  zip_code
# age
# 7          1       1           1         1
# 10         1       1           1         1
# 11         1       1           1         1
# 13         5       5           5         5
# 14         3       3           3         3
# ..       ...     ...         ...       ...
# 66         1       1           1         1
# 68         2       2           2         2
# 69         2       2           2         2
# 70         3       3           3         3
# 73         1       1           1         1
#
# [61 rows x 4 columns]

# %%
df_users.groupby("occupation").first()
# Out:
#                user_id  age gender zip_code
# occupation
# administrator        7   57      M    91344
# artist              23   30      F    48197
# doctor             138   46      M    53211
# educator            13   47      M    29206
# engineer            25   39      M    55107
# entertainment       16   21      M    10309
# executive            6   42      M    98101
# healthcare          60   50      M    06472
# homemaker           20   42      F    95660
# lawyer              10   53      M    90703
# librarian           19   40      M    02138
# marketing           46   27      F    46538
# none                57   16      M    84010
# other                2   53      F    94043
# programmer          17   30      M    06355
# retired            106   61      M    55125
# salesman           112   30      M    60613
# scientist           14   45      M    55106
# student              9   29      M    01002
# technician           1   24      M    85711
# ...

# %%
df_users.groupby("occupation").last()
# Out:
#                user_id  age gender zip_code
# occupation
# administrator      940   32      M    02215
# artist             920   30      F    90008
# doctor             935   42      M    66221
# educator           937   48      M    98072
# engineer           934   61      M    22902
# entertainment      926   49      M    01701
# executive          901   38      M    L1V3W
# healthcare         910   28      M    29301
# homemaker          898   23      M    61755
# lawyer             846   27      M    47130
# librarian          942   48      F    78209
# marketing          881   39      M    43017
# none               756   30      F    90247
# other              936   24      M    32789
# programmer         927   23      M    55428
# retired            900   60      M    18505
# salesman           925   18      F    49036
# scientist          930   28      F    07310
# student            943   22      M    77841
# technician         938   38      F    55038
# ...

# %%
df_users[df_users["zip_code"]=='32789']
# Out:
#      user_id  age gender occupation zip_code
# 935      936   24      M      other    32789

# %%
df_users[df_users["age"]==21]
# Out:
#      user_id  age gender     occupation zip_code
# 15        16   21      M  entertainment    10309
# 23        24   21      F         artist    94533
# 49        50   21      M         writer    52245
# 80        81   21      M        student    21218
# 117      118   21      M  administrator    90210
# 197      198   21      F        student    55414
# 227      228   21      F        student    22003
# 258      259   21      M        student    48823
# 275      276   21      M        student    95064
# 286      287   21      M       salesman    31211
# 322      323   21      M        student    19149
# 323      324   21      F        student    02176
# 444      445   21      M         writer    92653
# 495      496   21      F        student    55414
# 541      542   21      M        student    60515
# 588      589   21      M         lawyer    90034
# 602      603   21      M     programmer    47905
# 670      671   21      M     programmer    91919
# ...

# %%
df_users.groupby("occupation")[["age"]].mean()
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %%
df_users.query("occupation == 'homemaker'").groupby(['occupation', 'gender']).count()
# Out:
#                    user_id  age  zip_code
# occupation gender
# homemaker  F             6    6         6
#            M             1    1         1

# %%
df_users.query("occupation == 'administrator'").groupby(['occupation', 'gender']).count()
# Out:
#                       user_id  age  zip_code
# occupation    gender
# administrator F            36   36        36
#               M            43   43        43

# %% [markdown]
# # Sep 7 - Thursday

# %%
df_users.query("occupation == 'administrator'").groupby(['occupation', 'age']).count()
# Out:
#                    user_id  gender  zip_code
# occupation    age
# administrator 21         1       1         1
#               22         3       3         3
#               23         2       2         2
#               25         3       3         3
#               26         2       2         2
#               27         2       2         2
#               28         4       4         4
#               29         2       2         2
#               30         5       5         5
#               31         2       2         2
#               32         2       2         2
#               33         3       3         3
#               34         1       1         1
#               35         4       4         4
#               36         2       2         2
#               37         2       2         2
#               38         4       4         4
#               39         1       1         1
#               41         1       1         1
# ...

# %%
import numpy as np
import pandas as pd

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'],
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

# %%
regiment = pd.DataFrame(raw_data, columns = raw_data.keys())

# %%
regiment
# Out:
#       regiment company      name  preTestScore  postTestScore
# 0   Nighthawks     1st    Miller             4             25
# 1   Nighthawks     1st  Jacobson            24             94
# 2   Nighthawks     2nd       Ali            31             57
# 3   Nighthawks     2nd    Milner             2             62
# 4     Dragoons     1st     Cooze             3             70
# 5     Dragoons     1st     Jacon             4             25
# 6     Dragoons     2nd    Ryaner            24             94
# 7     Dragoons     2nd      Sone            31             57
# 8       Scouts     1st     Sloan             2             62
# 9       Scouts     1st     Piger             3             70
# 10      Scouts     2nd     Riani             2             62
# 11      Scouts     2nd       Ali             3             70

# %%
regiment.groupby('regiment').company.count()
# Out:
# regiment
# Dragoons      4
# Nighthawks    4
# Scouts        4
# Name: company, dtype: int64

# %%
regiment[regiment['regiment'] == 'Scouts'].groupby('regiment').count()
#Picks up only scouts
# Out:
#           company  name  preTestScore  postTestScore
# regiment
# Scouts          4     4             4              4

# %%
regiment[regiment['company'] == '2nd'].groupby('company').count()
# Out:
#          regiment  name  preTestScore  postTestScore
# company
# 2nd             6     6             6              6

# %%
regiment[regiment['preTestScore'] == 24].groupby('preTestScore').count()
# Out:
#               regiment  company  name  postTestScore
# preTestScore
# 24                   2        2     2              2

# %%
regiment[regiment['postTestScore'] == 94].groupby('postTestScore').count()
# Out:
#                regiment  company  name  preTestScore
# postTestScore
# 94                    2        2     2             2

# %%
regiment.groupby(['company', 'regiment']).size()
# Out:
# company  regiment
# 1st      Dragoons      2
#          Nighthawks    2
#          Scouts        2
# 2nd      Dragoons      2
#          Nighthawks    2
#          Scouts        2
# dtype: int64

# %%
regiment[regiment['postTestScore'] < 70 ].groupby('postTestScore').count()
# Out:
#                regiment  company  name  preTestScore
# postTestScore
# 25                    2        2     2             2
# 57                    2        2     2             2
# 62                    3        3     3             3

# %%
regiment[regiment['name'] == 'Ali' ].groupby('name').count()
# Out:
#       regiment  company  preTestScore  postTestScore
# name
# Ali          2        2             2              2

# %%
regiment[regiment['name'] == 'Ali' ].groupby('regiment').count()
# Out:
#             company  name  preTestScore  postTestScore
# regiment
# Nighthawks        1     1             1              1
# Scouts            1     1             1              1

# %%
regiment
# Out:
#       regiment company      name  preTestScore  postTestScore
# 0   Nighthawks     1st    Miller             4             25
# 1   Nighthawks     1st  Jacobson            24             94
# 2   Nighthawks     2nd       Ali            31             57
# 3   Nighthawks     2nd    Milner             2             62
# 4     Dragoons     1st     Cooze             3             70
# 5     Dragoons     1st     Jacon             4             25
# 6     Dragoons     2nd    Ryaner            24             94
# 7     Dragoons     2nd      Sone            31             57
# 8       Scouts     1st     Sloan             2             62
# 9       Scouts     1st     Piger             3             70
# 10      Scouts     2nd     Riani             2             62
# 11      Scouts     2nd       Ali             3             70

# %%
regiment[regiment['regiment'].isin(['Nighthawks','Dragoons'])].groupby('regiment').count()
# Out:
#             company  name  preTestScore  postTestScore
# regiment
# Dragoons          4     4             4              4
# Nighthawks        4     4             4              4

# %%
regiment[regiment['name'].isin(['Miller','Jacobson'])].groupby('name').count()
# Out:
#           regiment  company  preTestScore  postTestScore
# name
# Jacobson         1        1             1              1
# Miller           1        1             1              1

# %%
regiment[regiment['name'].isin(['Ali'])].groupby('name').count()
# Out:
#       regiment  company  preTestScore  postTestScore
# name
# Ali          2        2             2              2

# %% [markdown]
# # US Crime Rate Data Set 1960-2014

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'

# %%
df_uscrime = pd.read_csv(url)
df_uscrime
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
#info desc size shape head tail min max

# %%
#info
df_uscrime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
#Describe
df_uscrime.describe()
# Out:
#              Year    Population         Total       Violent      Property  \
# count    55.00000  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   1987.00000  2.461556e+08  1.060315e+07  1.188806e+06  9.412499e+06
# std      16.02082  4.166216e+07  3.175931e+06  4.597107e+05  2.738512e+06
# min    1960.00000  1.793232e+08  3.384200e+06  2.884600e+05  3.095700e+06
# 25%    1973.50000  2.106215e+08  9.096958e+06  9.253150e+05  8.060014e+06
# 50%    1987.00000  2.422829e+08  1.140151e+07  1.322390e+06  1.018259e+07
# 75%    2000.50000  2.833697e+08  1.308449e+07  1.432762e+06  1.160509e+07
# max    2014.00000  3.188571e+08  1.487290e+07  1.932270e+06  1.296110e+07
#
#              Murder  Forcible_Rape        Robbery  Aggravated_assault  \
# count     55.000000      55.000000      55.000000        5.500000e+01
# mean   17317.236364   72714.800000  416449.890909        6.811818e+05
# std     4267.442664   28278.006893  150506.403782        2.960255e+05
# ...

# %%
#Size
df_uscrime.groupby(['Year', 'Population', 'Robbery']).size()
# Out:
# Year  Population  Robbery
# 1960  179323175   107840     1
# 1961  182992000   106670     1
# 1962  185771000   110860     1
# 1963  188483000   116470     1
# 1964  191141000   130390     1
# 1965  193526000   138690     1
# 1966  195576000   157990     1
# 1967  197457000   202910     1
# 1968  199399000   262840     1
# 1969  201385000   298850     1
# 1970  203235298   349860     1
# 1971  206212000   387700     1
# 1972  208230000   376290     1
# 1973  209851000   384220     1
# 1974  211392000   442400     1
# 1975  213124000   470500     1
# 1976  214659000   427810     1
# 1977  216332000   412610     1
# 1978  218059000   426930     1
# 1979  220099000   480700     1
# 1980  225349264   565840     1
# 1981  229146000   592910     1
# 1982  231534000   553130     1
# 1983  233981000   506570     1
# 1984  236158000   485010     1
# 1985  238740000   497870     1
# 1986  240132887   542775     1
# 1987  242282918   517704     1
# 1988  245807000   542970     1
# ...

# %%
#Shape
df_uscrime.shape
# Out:
# (55, 12)

# %%
#Head
df_uscrime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
#Tail
df_uscrime.tail()
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 50  2010   309330219  10363873  1251248   9112625   14772          85593
# 51  2011   311587816  10258774  1206031   9052743   14661          84175
# 52  2012   313873685  10219059  1217067   9001992   14866          85141
# 53  2013   316497531   9850445  1199684   8650761   14319          82109
# 54  2014   318857056   9475816  1197987   8277829   14249          84041
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 50   369089              781844   2168457        6204601         739565
# 51   354772              752423   2185140        6151095         716508
# 52   355051              762009   2109932        6168874         723186
# 53   345095              726575   1931835        6018632         700294
# 54   325802              741291   1729806        5858496         689527

# %%
#Min
df_uscrime.min()
# Out:
# Year                       1960
# Population            179323175
# Total                   3384200
# Violent                  288460
# Property                3095700
# Murder                     8530
# Forcible_Rape             17190
# Robbery                  106670
# Aggravated_assault       154320
# Burglary                 912100
# Larceny_Theft           1855400
# Vehicle_Theft            328200
# dtype: int64

# %%
#Max
df_uscrime.max()
# Out:
# Year                       2014
# Population            318857056
# Total                  14872900
# Violent                 1932270
# Property               12961100
# Murder                    24700
# Forcible_Rape            109060
# Robbery                  687730
# Aggravated_assault      1135610
# Burglary                3795200
# Larceny_Theft           8142200
# Vehicle_Theft           1661700
# dtype: int64

# %%
df_uscrime.loc[df_uscrime['Year'] > 2000, ['Violent']]
# Out:
#     Violent
# 41  1439480
# 42  1423677
# 43  1383676
# 44  1360088
# 45  1390745
# 46  1418043
# 47  1408337
# 48  1392628
# 49  1325896
# 50  1251248
# 51  1206031
# 52  1217067
# 53  1199684
# 54  1197987

# %%
df_uscrime.iloc[[0, 5], [1, 5]]
# Out:
#    Population  Murder
# 0   179323175    9110
# 5   193526000    9960

# %%
df_uscrime.iloc[[0, 5], [1, 5]]
# Out:
#    Population  Murder
# 0   179323175    9110
# 5   193526000    9960

# %%
df_uscrime
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %% [markdown]
# # Merging two Data Sets

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %%
data1 = pd.DataFrame(raw_data_1, columns = ['subject_id', 'first_name', 'last_name'])
data2 = pd.DataFrame(raw_data_2, columns = ['subject_id', 'first_name', 'last_name'])
data3 = pd.DataFrame(raw_data_3, columns = ['subject_id','test_id'])

# %%
data_new = pd.concat([data1, data2])
data_new
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
data_new_row = pd.concat([data1, data2], axis=0)
data_new_row
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
data_new_col = pd.concat([data1, data2], axis=1)
data_new_col
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %%
pd.merge(data_new, data3, on='subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15
