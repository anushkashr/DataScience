# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '/content/Salary_Data.csv'
df = pd.read_csv('Salary_Data.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
#No non-numerical data here so we're not encoding categorical data
#ALso no missing values

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression

# %%
X = df.iloc[:, 0:1]
y = df.iloc[:, 1]
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
#Splitting data in train and test data set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state=1)

# %%
X_train
# Out:
#     YearsExperience
# 23              8.2
# 4               2.2
# 2               1.5
# 25              9.0
# 6               3.0
# 18              5.9
# 13              4.1
# 7               3.2
# 27              9.6
# 1               1.3
# 16              5.1
# 0               1.1
# 15              4.9
# 29             10.5
# 28             10.3
# 9               3.7
# 8               3.2
# 12              4.0
# 11              4.0
# 5               2.9

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Predicting salary of 5.5 YOE
reg.predict([[5.5]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([76507.00560722])

# %%
reg.coef_
# Out:
# array([9158.13919873])

# %%
reg.intercept_
# Out:
# 26137.24001419694

# %%
(9158.13919873*5.5)+26137.24001419694  #Almost exact with prediction 76507.00560722
# Out:
# 76507.00560721193
