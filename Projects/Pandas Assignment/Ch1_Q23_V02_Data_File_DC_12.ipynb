# %%
import pandas as pd

# %%
path = '/content/Ch1_Q23_V02_Data_File.xlsx'
df = pd.read_excel('Ch1_Q23_V02_Data_File.xlsx')

# %%
df = df.iloc[:,1:4]
df
# Out:
#       x2   x3  x4
# 0    Own  172   2
# 1   Rent  183   3
# 2    Own  172  60
# 3   Rent  148   7
# 4    Own  194   7
# ..   ...  ...  ..
# 95  Rent  209  16
# 96  Rent  204   7
# 97  Rent  114  52
# 98  Rent  128  10
# 99   Own  155  10
#
# [100 rows x 3 columns]

# %%
missing_values = df.isnull().sum()

# Print the number of missing values for each column
print("Number of missing values in each column:")
print(missing_values)
# Out:
# Number of missing values in each column:
# x2    0
# x3    0
# x4    0
# dtype: int64

# %%
# b. Remove all observations that have “Own” as the value for x2. Then remove all observations that have values lower than 150 for x3.
# How many observations remain in the data set?

# Remove observations with "Own" in x2
df = df[df['x2'] != 'Own']

# Remove observations with x3 values less than 150
df = df[df['x3'] >= 150]

# Count the remaining observations
remaining_observations = len(df)

print("Number of observations remaining in the dataset:", remaining_observations)
# Out:
# Number of observations remaining in the dataset: 26
