# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '/content/Ch2_Q57_Data_File.xlsx'
df = pd.read_excel('Ch2_Q57_Data_File.xlsx')

# %%
df = df.iloc[:, :4]
df
# Out:
#     Worker   Wage  Education  Age
# 0        1  17.54         12   76
# 1        2  20.93         10   61
# 2        3  12.94          8   75
# 3        4  19.34          6   38
# 4        5  24.12         12   59
# ..     ...    ...        ...  ...
# 75      76  25.64         14   74
# 76      77  38.77         21   41
# 77      78  21.87         15   75
# 78      79  27.54         20   46
# 79      80  23.66         12   49
#
# [80 rows x 4 columns]

# %%
#a. Construct a scatterplot of Wage and Education.
# Given the scatterplot, which statement best describes the relationship between Wage and Education?

plt.figure(figsize=(10,6))
plt.scatter(df['Wage'], df['Education'], color='blue')
plt.xlabel('Education')
plt.ylabel('Wage')
plt.title('Scatterplot of Wage and Education')
plt.show()

print('Analyzing the scatterplot, we can say that Wage and Education have a positive relationship')
# Out:
# Analyzing the scatterplot, we can say that Wage and Education have a positive relationship
