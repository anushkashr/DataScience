# %%
import pandas as pd

# %%
path = '/content/Ch3_Q5_Data_File.xlsx'
df = pd.read_excel('Ch3_Q5_Data_File.xlsx')

# %%
df_cleaned = df.iloc[:, :1]
df_cleaned
# Out:
#     Price
# 0     430
# 1     520
# 2     460
# 3     475
# 4     670
# 5     521
# 6     670
# 7     417
# 8     533
# 9     525
# 10    538
# 11    370
# 12    530
# 13    525
# 14    430
# 15    330
# 16    575
# 17    555
# 18    521
# 19    350
# 20    399
# 21    560
# 22    440
# 23    425
# 24    669
# 25    660
# 26    702
# 27    540
# 28    460
# 29    588
# 30    445
# 31    412
# 32    735
# 33    537
# 34    630
# 35    430

# %%
#Mean Sale Price
df_cleaned['Price'].mean().round(2)
# Out:
# 516.03

# %%
#Median Sale Price
df_cleaned['Price'].median().round(2)
# Out:
# 523.0
