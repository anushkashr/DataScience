# %%
import pandas as pd

# %%
path = '/content/Ch1_Q20_V12_Data_File (1).xlsx'
df = pd.read_excel('Ch1_Q20_V12_Data_File (1).xlsx')

# %%
df = df.iloc[:,:4]
df
# Out:
#     Observation    x1     x2     x3
# 0             1  33.0  371.0  189.0
# 1             2  28.0  752.0    NaN
# 2             3  24.0  673.0  204.0
# 3             4  17.0    NaN  151.0
# 4             5  20.0   66.0  191.0
# ..          ...   ...    ...    ...
# 86           87  18.0  412.0  137.0
# 87           88  28.0  629.0  139.0
# 88           89  22.0  167.0  125.0
# 89           90  35.0  842.0  126.0
# 90           91  38.0  180.0  151.0
#
# [91 rows x 4 columns]

# %%
#a. How many observations have x1 values greater than 30?
count_x1_greater_than_30 = df[df['x1'] > 30]['Observation'].count()

print("Number of observations with x1 values greater than 30:", count_x1_greater_than_30)
# Out:
# Number of observations with x1 values greater than 30: 17

# %%
#b. Sort the data by x1 in ascending order. What are the x1, x2, and x3 values of the first observation after the data are sorted?

df_sorted = df.sort_values(by='x1', ascending=True)

first_observation_values = df_sorted.iloc[0]

print('x1, x2, and x3 values of the first observation after the data are sorted:')
print("x1:", first_observation_values['x1'])
print("x2:", first_observation_values['x2'])
print("x3:", first_observation_values['x3'])
# Out:
# x1, x2, and x3 values of the first observation after the data are sorted:
# x1: 2.0
# x2: 335.0
# x3: 166.0

# %%
# c. Sort the data by x1 in descending order. What are the x1, x2, and x3 values of the first observation after the data are sorted?

df_sorted = df.sort_values(by='x1', ascending=False)

first_observation_values = df_sorted.iloc[0]

print('x1, x2, and x3 values of the first observation after the data are sorted:')
print("x1:", first_observation_values['x1'])
print("x2:", first_observation_values['x2'])
print("x3:", first_observation_values['x3'])
# Out:
# x1, x2, and x3 values of the first observation after the data are sorted:
# x1: 57.0
# x2: 218.0
# x3: 154.0

# %%
# d. How many missing values are there in x1, x2, and x3?

missing_x1 = df['x1'].isna().sum()
missing_x2 = df['x2'].isna().sum()
missing_x3 = df['x3'].isna().sum()

print("Missing values in x1:", missing_x1)
print("Missing values in x2:", missing_x2)
print("Missing values in x3:", missing_x3)
# Out:
# Missing values in x1: 1
# Missing values in x2: 3
# Missing values in x3: 5
