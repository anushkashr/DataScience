# %%
import pandas as pd

# %%
path = '/content/Ch3_Q7_Data_File.xlsx'
df=pd.read_excel("Ch3_Q7_Data_File.xlsx")

# %%
df.shape
# Out:
# (50, 8)

# %%
df_cleaned = df.iloc[:, :3]
df_cleaned
# Out:
#     Rank           State  Life_Expectancy
# 0      1          Hawaii             81.5
# 1      2       Minnesota             80.9
# 2      3      California             80.4
# 3      4        New York             80.4
# 4      5     Connecticut             80.2
# 5      6   Massachusetts             80.1
# 6      7    North Dakota             80.1
# 7      8            Utah             80.1
# 8      9        Colorado             79.9
# 9     10         Arizona             79.9
# 10    11    South Dakota             79.9
# 11    12   New Hampshire             79.7
# 12    13         Vermont             79.7
# 13    14         Florida             79.7
# 14    15            Iowa             79.7
# 15    16      New Jersey             79.7
# 16    17      Washington             79.7
# 17    18       Wisconsin             79.3
# 18    19    Rhode Island             79.3
# 19    20           Idaho             79.2
# 20    21        Nebraska             79.2
# ...

# %%
#Mean of Life Expectancy
df_cleaned['Life_Expectancy'].mean().round(2)
# Out:
# 78.42

# %%
#Median of Life Expectancy
df_cleaned['Life_Expectancy'].median().round(2)
# Out:
# 78.45
