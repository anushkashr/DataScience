# %%
# this is a case study for managing employees
# Name,salary,id,age,job poistion

# %%
# Add employee
# Delete by id
# Update name by id
# update salary by id
# update job position by id
# update age by id
# delete by name
# get_details by id
# get_details by name
#print all employees

# %%
class Employee:
  def __init__(self, emp_id, name, position, salary,age):
    self.emp_id = emp_id
    self.name = name
    self.position = position
    self.salary = salary
    self.age = age

  def display_info(self):
    print("Employee ID", self.emp_id)
    print("Name", self.name)
    print("Position", self.position)
    print("Salary", self.salary)
    print("Age", self.age)

class EmployeeManagementSystem:
  def __init__(self):
    self.employees = []

  def add_employee(self, emp):
    self.employees.append(emp)

  def remove_employee(self, emp_id):
    for emp in self.employees:
      if emp.emp_id == emp_id:
        self.employees.remove(emp)
        return True
    return False

  def update_name(self,emp_id,name):
    for emp in self.employees:
      if emp.emp_id == emp_id:
        emp.name= name
        return True
    return False

  def update_salary(self,emp_id,salary):
    for employee in self.employees:
      if employee.emp_id == emp_id:
        employee.salary= salary
        return True
    return False

  def update_position(self,emp_id,position):
    for employee in self.employees:
      if employee.emp_id == emp_id:
        employee.position= position
        return True
    return False

  def update_age(self,emp_id,age):
    for employee in self.employees:
      if employee.emp_id == emp_id:
        employee.age= age
        return True
    return False

  def delete_by_name(self,name):
    all_matching_names=[]
    for employee in self.employees:
      if employee.name == name:
        all_matching_names.append(employee)
    if len(all_matching_names)==0:
      return False
    elif len(all_matching_names)==1:
      self.employees.remove(all_matching_names[0])
      return True
    elif len(all_matching_names)>1:
      print("Duplicate names found please select the id you want to remove")
      all_ids=[]
      for emps in all_matching_names:
        print("ID :- ",emps.emp_id)
        all_ids.append(emps.emp_id)
      id_to_remove=int(input("Please choose the id you want to remove :- "))
      if id_to_remove in all_ids:
        self.employees.remove(all_matching_names[all_ids.index(id_to_remove)])
        return True
      else:
        return False

  def details_by_id(self,emp_id):
    for employee in self.employees:
      if employee.emp_id == emp_id:
        employee.display_info()

  def details_by_name(self,name):
    for employee in self.employees:
      if employee.name == name:
        employee.display_info()

  def details_all_employees(self):
    print("Check length",len(self.employees))
    for employee in self.employees:
        employee.display_info()
        print("====================")

  def write_data(self):
    with open("employe_data.txt",'a') as f:
      for employee in self.employees:
        f.write(str(employee.emp_id)+","+str(employee.name)+","+str(employee.position)+","+str(employee.salary)+","+str(employee.age)+"\n")

# %%
emp_managed_system=EmployeeManagementSystem()
while True:
  print("Please choose the option")
  print("1) Add Employee")
  print("2) Delete Employee by ID")
  print("3) Delete Employee by Name")
  print("4) All details")
  print("5) Exit")
  choice=input("Please choose an option ")
  if choice=='1':
    name=choice=input("Please enter Employee name ")
    salary=choice=input("Please enter Employee salary ")
    age=choice=input("Please enter Employee age ")
    position=choice=input("Please enter Employee position ")
    id=len(emp_managed_system.employees)
    emp_temp=Employee(id,name,position,salary,age)
    emp_managed_system.add_employee(emp_temp)
  elif choice=='2':
    id=int(input("Please enter Employee id you want to remove "))

    if emp_managed_system.remove_employee(id):
        print("Employee Removed Successfully")
    else:
        print("ID not found, could not remove the employee")

  elif choice == '3':
    name = input("Please enter the name of the employee you want to remove: ")
    if emp_managed_system.delete_by_name(name):
      print("Employee(s) Removed Successfully")
    else:
      print("No matching names found or removal unsuccessful")

  elif choice == '4':
    emp_managed_system.details_all_employees()

  elif choice=='5':
    print("Bye!")
    emp_managed_system.write_data()
    break
  else:
    print("Invalid option. Please choose a valid option.")
# Out:
# Please choose the option
# 1) Add Employee
# 2) Delete Employee by ID
# 3) Delete Employee by Name
# 4) All details
# 5) Exit
# Please choose an option 1
# Please enter Employee name Anushka
# Please enter Employee salary 90000
# Please enter Employee age 23
# Please enter Employee position dev
# Please choose the option
# 1) Add Employee
# 2) Delete Employee by ID
# 3) Delete Employee by Name
# 4) All details
# 5) Exit
# Please choose an option 1
# Please enter Employee name Lily
# Please enter Employee salary 80000
# Please enter Employee age 21
# Please enter Employee position QA
# Please choose the option
# 1) Add Employee
# 2) Delete Employee by ID
# 3) Delete Employee by Name
# 4) All details
# 5) Exit
# Please choose an option 1
# Please enter Employee name Anna
# Please enter Employee salary 60000
# Please enter Employee age 22
# Please enter Employee position dev-test
# Please choose the option
# 1) Add Employee
# 2) Delete Employee by ID
# 3) Delete Employee by Name
# 4) All details
# 5) Exit
# Please choose an option 4
# Check length 3
# Employee ID 0
# Name Anushka
# Position dev
# Salary 90000
# Age 23
# ====================
# Employee ID 1
# Name Lily
# Position QA
# Salary 80000
# Age 21
# ====================
# Employee ID 2
# Name Anna
# Position dev-test
# Salary 60000
# Age 22
# ====================
# Please choose the option
# 1) Add Employee
# 2) Delete Employee by ID
# 3) Delete Employee by Name
# 4) All details
# 5) Exit
# Please choose an option 2
# Please enter Employee id you want to remove 1
# Employee Removed Successfully
# Please choose the option
# 1) Add Employee
# 2) Delete Employee by ID
# 3) Delete Employee by Name
# 4) All details
# 5) Exit
# Please choose an option 4
# Check length 2
# Employee ID 0
# Name Anushka
# Position dev
# Salary 90000
# Age 23
# ====================
# Employee ID 2
# Name Anna
# Position dev-test
# Salary 60000
# Age 22
# ====================
# Please choose the option
# 1) Add Employee
# 2) Delete Employee by ID
# 3) Delete Employee by Name
# 4) All details
# 5) Exit
# Please choose an option 3
# Please enter the name of the employee you want to remove: Anna
# Employee(s) Removed Successfully
# Please choose the option
# 1) Add Employee
# 2) Delete Employee by ID
# 3) Delete Employee by Name
# 4) All details
# 5) Exit
# Please choose an option 4
# Check length 1
# Employee ID 0
# Name Anushka
# Position dev
# Salary 90000
# Age 23
# ====================
# Please choose the option
# 1) Add Employee
# 2) Delete Employee by ID
# 3) Delete Employee by Name
# 4) All details
# 5) Exit
# Please choose an option 5
# Bye!
